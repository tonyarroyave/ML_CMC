# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
from pandas.plotting import radviz

# %%
def open_file(name, path):
    file_path = path + name
    return pd.read_csv(file_path)

def get_avrg(df_data):
    df_data['Open*'] = pd.to_numeric(df_data['Open*'], errors='coerce').fillna(0.0)
    df_data['Close**'] = pd.to_numeric(df_data['Close**'], errors='coerce').fillna(0.0)
    return (df_data['Open*']+df_data['Close**'])/2

def create_time_col(path):
    file_path = path + 'bitcoin.csv'
    btc_df = pd.read_csv(file_path)
    return pd.to_datetime(btc_df['Date'])

# %%
plt.figure(figsize=(14,6))
the_path = os.getcwd()
data_path = the_path + '/data/'
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
target = 'bitcoin'

# %%
count = 0
big_df = pd.DataFrame()
for file in onlyfiles:
    count += 1
    df_data = open_file(file, data_path)
    col_avrg = get_avrg(df_data)
    if len(col_avrg) == 183:
        big_df[file.split('.')[0]] = col_avrg
big_df.head(5)
# Out:
#    senderon   aventus  neblio  dashcoin  cannation  emercoin    zcash  \
# 0  0.004921  0.875257   4.175  0.020592   0.009185     3.055  174.650
# 1  0.004934  0.869092   3.910  0.018113   0.007607     2.805  168.505
# 2  0.004818  0.881495   3.675  0.018848   0.007610     2.625  163.850
# 3  0.004524  0.860764   3.640  0.018697   0.007782     2.470  158.750
# 4  0.004500  0.834589   3.725  0.018286   0.007187     2.385  160.165
#
#    aurumcoin       msd  platinumbar    ...     condensate  terracoin  \
# 0     20.010  0.003632     0.984570    ...       0.004596   0.117652
# 1     19.855  0.003670     0.881946    ...       0.004828   0.114746
# 2     19.530  0.003750     0.807401    ...       0.004743   0.110252
# 3     18.510  0.003620     0.747138    ...       0.004554   0.100846
# 4     18.405  0.003599     0.827225    ...       0.004620   0.095866
#
#       modum    ark  storjcoin-x  russiacoin  novacoin    snovio  tezos  \
# 0  1.025904  1.485     0.640941    0.212698     2.735  0.010117  3.430
# 1  0.976308  1.380     0.636612    0.194623     2.690  0.009965  4.185
# 2  0.931698  1.285     0.668215    0.190042     2.665  0.009555  4.235
# 3  0.880212  1.225     0.700039    0.180976     2.565  0.008380  3.810
# 4  0.891655  1.255     0.706336    0.209086     2.560  0.008093  3.565
#
#        linx
# 0  0.024385
# 1  0.023939
# 2  0.023834
# 3  0.023384
# 4  0.024573
#
# [5 rows x 863 columns]

# %%
big_df['Date'] = create_time_col(data_path)
big_df.set_index('Date', inplace=True)
big_df.head(5)
# Out:
#             senderon   aventus  neblio  dashcoin  cannation  emercoin  \
# Date
# 2018-07-02  0.004921  0.875257   4.175  0.020592   0.009185     3.055
# 2018-07-01  0.004934  0.869092   3.910  0.018113   0.007607     2.805
# 2018-06-30  0.004818  0.881495   3.675  0.018848   0.007610     2.625
# 2018-06-29  0.004524  0.860764   3.640  0.018697   0.007782     2.470
# 2018-06-28  0.004500  0.834589   3.725  0.018286   0.007187     2.385
#
#               zcash  aurumcoin       msd  platinumbar    ...     condensate  \
# Date                                                     ...
# 2018-07-02  174.650     20.010  0.003632     0.984570    ...       0.004596
# 2018-07-01  168.505     19.855  0.003670     0.881946    ...       0.004828
# 2018-06-30  163.850     19.530  0.003750     0.807401    ...       0.004743
# 2018-06-29  158.750     18.510  0.003620     0.747138    ...       0.004554
# 2018-06-28  160.165     18.405  0.003599     0.827225    ...       0.004620
#
#             terracoin     modum    ark  storjcoin-x  russiacoin  novacoin  \
# Date
# 2018-07-02   0.117652  1.025904  1.485     0.640941    0.212698     2.735
# 2018-07-01   0.114746  0.976308  1.380     0.636612    0.194623     2.690
# 2018-06-30   0.110252  0.931698  1.285     0.668215    0.190042     2.665
# 2018-06-29   0.100846  0.880212  1.225     0.700039    0.180976     2.565
# 2018-06-28   0.095866  0.891655  1.255     0.706336    0.209086     2.560
#
#               snovio  tezos      linx
# Date
# 2018-07-02  0.010117  3.430  0.024385
# 2018-07-01  0.009965  4.185  0.023939
# 2018-06-30  0.009555  4.235  0.023834
# 2018-06-29  0.008380  3.810  0.023384
# 2018-06-28  0.008093  3.565  0.024573
#
# [5 rows x 863 columns]

# %%
"""Linear correlation analysis"""
correlations = big_df.corr()[target].sort_values(ascending=False)

# %%
"""Getting the coins with higher correlations"""
keys_h_corr = correlations.keys()
keys = []
vals = []
for curr_corr in keys_h_corr:
    if abs(correlations[curr_corr]) > 0.70 and abs(correlations[curr_corr]) != 1.0:
        keys.append(curr_corr)
        vals.append(correlations[curr_corr])
h_corr = pd.Series(vals, index=keys)

# %%
h_corr
# Out:
# the-champcoin            0.992986
# novacoin                 0.977063
# humaniq                  0.972703
# waves                    0.969369
# dash                     0.968445
# huntercoin               0.968180
# vertcoin                 0.967741
# monacoin                 0.964394
# evergreencoin            0.962836
# omni                     0.961319
# exclusivecoin            0.960664
# potcoin                  0.960280
# blackcoin                0.960082
# zcoin                    0.958367
# curecoin                 0.957868
# bitcoin-plus             0.957480
# sibcoin                  0.957012
# monero                   0.955899
# factom                   0.955287
# adx-net                  0.954524
# tenx                     0.954181
# dynamic                  0.953711
# internet-of-people       0.952623
# clams                    0.951402
# eidoo                    0.950066
# wings                    0.949718
# komodo                   0.949716
# foldingcoin              0.949509
# request-network          0.949432
# expanse                  0.948706
#                            ...
# nubits                   0.723124
# noblecoin                0.720683
# rlc                      0.720240
# b2bx                     0.720225
# brat                     0.719533
# version                  0.718885
# upfiring                 0.718166
# aelf                     0.717249
# hive-project             0.716545
# decentraland             0.715577
# dubaicoin-dbix           0.715500
# votecoin                 0.715087
# alqo                     0.713769
# centurion                0.712548
# atlant                   0.710853
# adzcoin                  0.710556
# zsecoin                  0.710340
# maecenas                 0.710123
# tron                     0.708933
# global-cryptocurrency    0.707615
# ethereum-dark            0.707133
# bigup                    0.707036
# tajcoin                  0.707028
# pandacoin-pnd            0.706616
# droxne                   0.706343
# luxcoin                  0.705428
# dentacoin                0.704673
# adshares                 0.703769
# fuzzballs                0.700776
# bitcny                  -0.758850
# Length: 695, dtype: float64
